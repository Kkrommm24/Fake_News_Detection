# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from langdetect import detect

# Load data
file_path = '../Dataset_Original/VFND/vn_news_223_tdlfr.csv'
data = pd.read_csv(file_path)

# %%
data.head()
# Out:
#                                                 text               domain  \
# 0  Thủ tướng Abe cúi đầu xin lỗi vì hành động phi...         binhluan.biz
# 1  Thủ tướng Nhật cúi đầu xin lỗi vì tinh thần ph...         www.ipick.vn
# 2  Choáng! Cơ trưởng đeo khăn quàng quẩy banh nóc...       tintucqpvn.net
# 3  Chưa bao giờ nhạc Kpop lại dễ hát đến thế!!!\n...       tintucqpvn.net
# 4  Đại học Hutech sẽ áp dụng cải cách "Tiếq Việt"...  www.gioitreviet.net
#
#    label
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
print(data['label'].value_counts())
# Out:
# label
# 0    123
# 1    100
# Name: count, dtype: int64

# %%
print(data['domain'].value_counts())
# Out:
# domain
# vnexpress.net              73
# tinvn.info                 68
# dantri.com.vn              14
# thethao.tuoitre.vn         10
# news.zing.vn                6
# thoibao.today               6
# tuoitre.vn                  5
# thanhnien.vn                5
# tintucqpvn.net              5
# phapluat.news               3
# kinhdoanh.vnexpress.net     3
# thegioitre.vn               2
# giadinhtiepthi.com          2
# giaitri.vnexpress.net       2
# thoibao.de                  2
# www.ipick.vn                2
# doisong.vnexpress.net       2
# dulich.vnexpress.net        1
# sohoa.vnexpress.net         1
# binhluan.biz                1
# https://news.zing.vn        1
# www.vietgiaitri.com/        1
# sorry.vn                    1
# laodong.vn                  1
# haiduong.tintuc.vn          1
# baoangiang.com.vn           1
# autoxe.net                  1
# suckhoe.vnexpress.net       1
# www.gioitreviet.net         1
# baonuocmy.com               1
# Name: count, dtype: int64

# %%
# Out:
#                      domain  trustworthiness
# 0                autoxe.net              0.0
# 1         baoangiang.com.vn              0.0
# 2             baonuocmy.com              0.0
# 3              binhluan.biz              0.0
# 4             dantri.com.vn              1.0
# 5     doisong.vnexpress.net              1.0
# 6      dulich.vnexpress.net              1.0
# 7        giadinhtiepthi.com              0.0
# 8     giaitri.vnexpress.net              1.0
# 9        haiduong.tintuc.vn              0.0
# 10     https://news.zing.vn              1.0
# 11  kinhdoanh.vnexpress.net              1.0
# 12               laodong.vn              0.0
# 13             news.zing.vn              1.0
# 14            phapluat.news              0.0
# 15      sohoa.vnexpress.net              1.0
# 16                 sorry.vn              0.0
# 17    suckhoe.vnexpress.net              0.0
# 18             thanhnien.vn              1.0
# 19            thegioitre.vn              0.0
# 20       thethao.tuoitre.vn              1.0
# 21               thoibao.de              0.0
# 22            thoibao.today              0.0
# 23           tintucqpvn.net              0.0
# 24               tinvn.info              0.0
# 25               tuoitre.vn              1.0
# 26            vnexpress.net              1.0
# 27      www.gioitreviet.net              0.0
# 28             www.ipick.vn              0.0
# 29     www.vietgiaitri.com/              0.0

# %% [markdown]
# # Missing & duplicate values

# %%
data.isnull().sum()
# Out:
# text            0
# domain          0
# label           0
# true_counts     0
# false_counts    0
# dtype: int64

# %%
# Numeber of unique values in each column
num_unique = data.nunique()

print(num_unique)
# Out:
# text            222
# domain           30
# label             2
# true_counts       2
# false_counts      2
# dtype: int64

# %%
# Find duplicate texts and their corresponding domains
duplicate_texts = data[data.duplicated('text', keep=False)]
print(duplicate_texts)
# Out:
#                                                  text      domain  label  \
# 41  Những dấu hiệu nhận biết nhà bạn đang có ma và...  tinvn.info      1
# 74  Những dấu hiệu nhận biết nhà bạn đang có ma và...  tinvn.info      1
#
#     true_counts  false_counts
# 41            0             1
# 74            0             1

# %% [markdown]
# # Distribution of domain

# %%
data['domain'],_ = pd.factorize(data['domain'])
correlation = data [['domain','label']].corr()
print(correlation)
# Out:
#           domain     label
# domain  1.000000 -0.761575
# label  -0.761575  1.000000

# %%
import pandas as pd

# Giả sử bạn đã có DataFrame data
# data = pd.read_csv('path_to_your_data.csv')

def calculate_trustworthiness(row):
    total_statements = row['true_counts'] + row['false_counts']
    if total_statements == 0:
        return 0
    trustworthiness = row['true_counts'] / total_statements
    return trustworthiness

# Đảm bảo cột 'true_counts' và 'false_counts' được tính từ nhãn 'true' và 'false'
data['true_counts'] = data['label'].apply(lambda x: 1 if x == 0 else 0)
data['false_counts'] = data['label'].apply(lambda x: 1 if x == 1 else 0)


# Nhóm dữ liệu theo 'domain' và tính tổng
speaker_group = data.groupby('domain').sum().reset_index()

# Tính độ uy tín
speaker_group['trustworthiness'] = speaker_group.apply(calculate_trustworthiness, axis=1)

# Hiển thị độ uy tín
print(speaker_group[['domain', 'trustworthiness']])
# Out:
#                      domain  trustworthiness
# 0                autoxe.net              0.0
# 1         baoangiang.com.vn              0.0
# 2             baonuocmy.com              0.0
# 3              binhluan.biz              0.0
# 4             dantri.com.vn              1.0
# 5     doisong.vnexpress.net              1.0
# 6      dulich.vnexpress.net              1.0
# 7        giadinhtiepthi.com              0.0
# 8     giaitri.vnexpress.net              1.0
# 9        haiduong.tintuc.vn              0.0
# 10     https://news.zing.vn              1.0
# 11  kinhdoanh.vnexpress.net              1.0
# 12               laodong.vn              0.0
# 13             news.zing.vn              1.0
# 14            phapluat.news              0.0
# 15      sohoa.vnexpress.net              1.0
# 16                 sorry.vn              0.0
# 17    suckhoe.vnexpress.net              0.0
# 18             thanhnien.vn              1.0
# 19            thegioitre.vn              0.0
# 20       thethao.tuoitre.vn              1.0
# 21               thoibao.de              0.0
# 22            thoibao.today              0.0
# 23           tintucqpvn.net              0.0
# 24               tinvn.info              0.0
# 25               tuoitre.vn              1.0
# 26            vnexpress.net              1.0
# 27      www.gioitreviet.net              0.0
# 28             www.ipick.vn              0.0
# 29     www.vietgiaitri.com/              0.0

# %%
# Re-import matplotlib for plotting
domain_counts = data['domain'].value_counts()
plt.figure(figsize=(12, 8))
ax = domain_counts.plot(kind='bar')
plt.title('Distribution of Domains')
plt.xlabel('Domain')
plt.ylabel('Number of Articles')

# Rotate x-ticks and set labels
ax.set_xticklabels(domain_counts.index, rotation=90, ha='center')
plt.show()

# %%
data = pd.read_csv(file_path)
data['domain_length'] = data['domain'].apply(len)
print(data['domain_length'].describe())
# Out:
# count    223.000000
# mean      12.672646
# std        2.920187
# min        8.000000
# 25%       10.000000
# 50%       13.000000
# 75%       13.000000
# max       23.000000
# Name: domain_length, dtype: float64

# %%
data['domain_length'],_ = pd.factorize(data['domain_length'])
correlation = data [['domain_length','label']].corr()
print(correlation)
# Out:
#                domain_length     label
# domain_length       1.000000  0.221686
# label               0.221686  1.000000

# %%
# Out:
#                      domain  trustworthiness
# 0                autoxe.net              0.0
# 1         baoangiang.com.vn              0.0
# 2             baonuocmy.com              0.0
# 3              binhluan.biz              0.0
# 4             dantri.com.vn              1.0
# 5     doisong.vnexpress.net              1.0
# 6      dulich.vnexpress.net              1.0
# 7        giadinhtiepthi.com              0.0
# 8     giaitri.vnexpress.net              1.0
# 9        haiduong.tintuc.vn              0.0
# 10     https://news.zing.vn              1.0
# 11  kinhdoanh.vnexpress.net              1.0
# 12               laodong.vn              0.0
# 13             news.zing.vn              1.0
# 14            phapluat.news              0.0
# 15      sohoa.vnexpress.net              1.0
# 16                 sorry.vn              0.0
# 17    suckhoe.vnexpress.net              0.0
# 18             thanhnien.vn              1.0
# 19            thegioitre.vn              0.0
# 20       thethao.tuoitre.vn              1.0
# 21               thoibao.de              0.0
# 22            thoibao.today              0.0
# 23           tintucqpvn.net              0.0
# 24               tinvn.info              0.0
# 25               tuoitre.vn              1.0
# 26            vnexpress.net              1.0
# 27      www.gioitreviet.net              0.0
# 28             www.ipick.vn              0.0
# 29     www.vietgiaitri.com/              0.0

# %% [markdown]
# # Distribution of text length

# %%
# Calculate the length of each 'text'
data['text_length'] = data['text'].apply(len)
print(data['text_length'].describe())
# Out:
# count      223.000000
# mean      2539.771300
# std       1780.532008
# min        309.000000
# 25%       1286.000000
# 50%       2009.000000
# 75%       3300.500000
# max      10019.000000
# Name: text_length, dtype: float64

# %%
# Describe 'text_length' for label 0
print(data[data['label'] == 0]['text_length'].describe())
# Describe 'text_length' for label 1
print(data[data['label'] == 1]['text_length'].describe())
# Out:
# count     123.000000
# mean     2398.170732
# std      1551.610452
# min       309.000000
# 25%      1271.000000
# 50%      2104.000000
# 75%      2953.000000
# max      6970.000000
# Name: text_length, dtype: float64
# count      100.000000
# mean      2713.940000
# std       2021.578585
# min        755.000000
# 25%       1323.750000
# 50%       1860.500000
# 75%       3424.500000
# max      10019.000000
# Name: text_length, dtype: float64

# %%
data['text_length'].hist(bins=50)
plt.title('Histogram of text Length')
plt.xlabel('text Length')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Below 1000 characters

# %%
plt.hist(data['text_length'], bins=50, range=[1,1000 ])
plt.title('Distribution of text length below 10 characters')
plt.xlabel('Text length')
plt.ylabel('Frequency')
plt.show()

# %%
print(data[data['text_length']<1000]['text'])
# Out:
# 1      Thủ tướng Nhật cúi đầu xin lỗi vì tinh thần ph...
# 5      Cười vỡ bụng khi tiếng CẢI CÁCH "vuông tròn" x...
# 31     Đứng bán nem chua rán, gái xinh khiến dân mạng...
# 32     Đi cả đêm mới về, bà mẹ tá hoả thấy mặt con bị...
# 38     Cảm giác như trục quay trái đất sắp gãy khi xe...
# 50     Tưởng ổ trứng gà mang về ấp thành con, thanh n...
# 57     Dụ em gái cosplay mới quen gửi ảnh trong bồn t...
# 76     Cứ tưởng đào được trứng khủng long, người đàn ...
# 81     Nếu thấy thứ này thò lên ngoài vườn nhà, đừng ...
# 86     Thích dạng háng check-in cho thoáng, thiếu nữ ...
# 87     Nhận xăm “chỗ kín” cho thiếu nữ, tái mặt vì th...
# 90     Hẹn hò người thương nơi sân trường, nam sinh k...
# 108    Thanh Bùi ôm vợ khóc trên sân khấu\n"Nếu như k...
# 115    Hơn 55 tỷ đồng nâng cấp 8,5 km đại lộ Võ Văn K...
# 117    Đường Sài Gòn kẹt từ sáng đến trưa\nĐường Quốc...
# 123    An Giang cấm sử dụng âm thanh dụ chim yến tron...
# 138    Khải Hoàn Môn tan hoang sau cuộc bạo loạn lớn ...
# 139    Hà Nội, Sài Gòn cờ rợp đường mừng chiến thắng ...
# 140    Hai tài xế đánh nhau vì giành đường tại 'nút c...
# 148    Ôtô ở Sài Gòn cuốn hàng loạt người, xe máy vào...
# 150    Nữ tiếp viên gốc Hoa bị chụp trộm gây sốt mạng...
# 162    Vẻ xa xỉ của Song Hye Kyo khi đóng quý cô trâm...
# 165    Người Hà Nội chen chân chụp ảnh trong vườn cúc...
# 167    Tài xế ép hàng loạt xe máy, ôtô nhập đúng làn ...
# 168    Bộ sưu tập xe trị giá 1,3 triệu USD của Neymar...
# 173    Tài xế xe sang che biển số để lùi trên cao tốc...
# 194    Ôtô Mercedes lật nhiều vòng trên đường Sài Gòn...
# 205    'Hoa hậu quần vợt' Bouchard trổ tài đá bóng\nK...
# 207    Federer đụng Djokovic ở bán kết Giải quần vợt ...
# 216    Đuổi theo kẻ ném chất bẩn, chủ nhà bị gãy chân...
# 217    Đối tượng cuối cùng trong vụ trốn khỏi trại tạ...
# Name: text, dtype: object

# %%
plt.hist(data['text_length'], bins=50, range=[1000, 4500])
plt.title('Distribution of text length from 1000 to 2500 characters')
plt.xlabel('Text length')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(data['text_length'], bins=50, range=[4500, 7000])
plt.title('Distribution of text length above 4500 characters')
plt.xlabel('Text length')
plt.ylabel('Frequency')
plt.show()

# %%
print(data[data['text_length']>4500]['text'])
# Out:
# 4      Đại học Hutech sẽ áp dụng cải cách "Tiếq Việt"...
# 7      Hại não với Vọng Cổ mang tên Vuông Tròn Tam Gi...
# 8      Kinh hoàng bé gái bị chó nhà tấn công, cắn vào...
# 10     KHẨN CẤP: Hàng loạt trẻ em nhập viện vì ngộ độ...
# 23     Bi kịch ngoại tình với bố chồng\n\n\nVậy là sa...
# 24     Đức từ chối cấp Visa cho đoàn công tác nhà nướ...
# 26     Sự thật kinh hoàng về nước Mỹ qua lời kể của m...
# 37     Hàng ngàn người Hà Nội đứng hình khi chứng kiế...
# 39     Người đàn ông bị “ma dắt đi chơi” cho tới chết...
# 41     Những dấu hiệu nhận biết nhà bạn đang có ma và...
# 48     Sốc với những loại “bùa ngải” có thật dấu hiệu...
# 59     Vợ chết 3 ngày về báo mộng, chồng dỡ trần nhà ...
# 60     Đêm nào mẹ cũng báo mộng cho con trai và cái k...
# 61     Cưới vợ cho con trai, bố mẹ đặt 200 mâm cỗ như...
# 62     Chấp nhận đổ vỏ cho con nhỏ bạn thân và cái kế...
# 74     Những dấu hiệu nhận biết nhà bạn đang có ma và...
# 98     Chữa hết bệnh câm cho vợ, người chồng cay đắng...
# 103    Go-Jek và Grab giành giật thị trường Indonesia...
# 110    Sài Gòn mưa như trút nước, cây đổ đè người tử ...
# 119    Đường chạy của người phụ nữ cụt chân\nTTO - Nă...
# 124    Băng trộm SH đâm chết các 'hiệp sĩ': Tấm lòng ...
# 158    Người Việt ở Paris: Cuộc sống vẫn diễn ra bình...
# 159    Cuộc sống của những người Thủ Thiêm cố giữ đất...
# 161    Cuộc sống ở 'ốc đảo' biệt thự ngoại thành Hà N...
# 163    Thương em bị mẹ vợ đoạ đày, anh trai gây án gi...
# 170    Thói quen lái xe giúp tiết kiệm 25% nhiên liệu...
# 171    Cụ bà Nhật ăn cắp vặt để vào tù, trốn tránh cô...
# 172    Nam cảnh sát Mỹ truy đuổi nữ sinh viên để sàm ...
# 177    Giáo viên đề nghị bỏ thi trắc nghiệm môn Lịch ...
# 206    “Quần vợt VN coi chừng lạc đường như Thái Lan”...
# 214    Vụ chạy thận chết người: Cựu giám đốc bệnh việ...
# Name: text, dtype: object

# %% [markdown]
# ### Text_length and label correlation

# %%
correlation = data[['text_length', 'label']].corr()
print(correlation)
# Out:
#              text_length     label
# text_length     1.000000  0.088398
# label           0.088398  1.000000

# %%
# Plot word cloud function
def plot_wordcloud(text):
    wordcloud = WordCloud(width=800, height=600,
                          background_color='white',
                          stopwords=None,
                          min_font_size=10).generate(text)
    plt.figure(figsize=(8, 8), facecolor=None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad=0)
    plt.show()

# Generate and plot word cloud for all texts_texts = ' '.join(data['text'].astype(str))

# %%
true_text = ' '.join(data[data['label'] == 0]['text'].astype(str))
fake_text = ' '.join(data[data['label'] == 1]['text'].astype(str))
plot_wordcloud(true_text)
plot_wordcloud(fake_text)
